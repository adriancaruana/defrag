# %%
experiment_path = None
raw = False
change_root = True
mimic_experiment = False

# %%
import sys
sys.path.append("/workspaces/defrag/")
from gallery import view_results, Path
view_results(Path(experiment_path), raw=raw, change_root=change_root)

# %%
# %matplotlib inline
from image_processor import plot
from gallery import view_results, Path

# experiment_path = Path("/workspaces/defrag/experiments/mimic_experiment_breast_soft_hierarchical_5")
plot(Path(experiment_path))
# Out:
# Using soft GTG plot
